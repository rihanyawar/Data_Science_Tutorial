# %%
import pandas as pd
import numpy as np

# %%
goggle= pd.read_csv("Datasets/google.csv")

# %%
goggle.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
pd.Timestamp("12th Jan 2022 8:12 PM")
# Out:
# Timestamp('2022-01-12 20:12:00')

# %%
pd.DatetimeIndex(["12 jan 2022  8:20", "14 Feb 2022", "14 Mar 2034"])
# Out:
# DatetimeIndex(['2022-01-12 08:20:00', '2022-02-14 00:00:00',
#                '2034-03-14 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
a= pd.Timestamp("6 Jan 2023")
b= pd.Timestamp("6 Jan 2022")

# %%
b-a
# Out:
# Timedelta('-365 days +00:00:00')

# %%
c=pd.Timedelta(days=5)

# %%
a+c
# Out:
# Timestamp('2023-01-11 00:00:00')

# %%
pd.date_range(start='2023-1-6', end='2023-4-2', freq='D') +c
# Out:
# DatetimeIndex(['2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14',
#                '2023-01-15', '2023-01-16', '2023-01-17', '2023-01-18',
#                '2023-01-19', '2023-01-20', '2023-01-21', '2023-01-22',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-28', '2023-01-29', '2023-01-30',
#                '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03',
#                '2023-02-04', '2023-02-05', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-11',
#                '2023-02-12', '2023-02-13', '2023-02-14', '2023-02-15',
#                '2023-02-16', '2023-02-17', '2023-02-18', '2023-02-19',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-25', '2023-02-26', '2023-02-27',
#                '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03',
# ...

# %%
df= pd.read_csv("Datasets/deliveries1.csv")

# %%
df.head()
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92
# 3    7/21/92      11/20/97
# 4     9/2/93       6/10/98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    object
#  1   delivery_date  501 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])
# Out:
# C:\Users\mohdr\AppData\Local\Temp\ipykernel_23148\3472121163.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# C:\Users\mohdr\AppData\Local\Temp\ipykernel_23148\3472121163.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[ns]
#  1   delivery_date  501 non-null    datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 8.0 KB

# %%
df['delivery_time_period'] = df['delivery_date'] - df['order_date']

# %%
df.head()
# Out:
#   order_date delivery_date delivery_time_period
# 0 1998-05-24    1999-02-05             257 days
# 1 1992-04-22    1998-03-06            2144 days
# 2 1991-02-10    1992-08-26             563 days
# 3 1992-07-21    1997-11-20            1948 days
# 4 1993-09-02    1998-06-10            1742 days

# %%
df['delivery_time_period'].mean()
# Out:
# Timedelta('1217 days 22:53:53.532934128')

# %%
goggle.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close   Volume
# 4466  2295.850098  1164100
# 4467  2334.030029  1078800
# 4468  2248.020020  1399100
# 4469  2214.909912  1459600
# 4470  2186.260010  1878100
