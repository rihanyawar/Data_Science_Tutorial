# %%
import numpy as np
import pandas as pd

# %%
a= np.array([1,2,3,4])

# %%
a*4
# Out:
# array([ 4,  8, 12, 16])

# %%
type([1,2,3,4])
# Out:
# list

# %%
s=['cat', 'rat',None, 'Mat']
[i. startswith('c') for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 s=['cat', 'rat',None, 'Mat']
# ----> 2 [i. startswith('c') for i in s]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
s= pd.Series(['cat', 'rat',None, 'Mat'])
s.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df= pd.read_csv("Datasets/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Last_Name']= df['Name'].str.split(',').str.get(0)

# %%
df['Last_Name']
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Last_Name, Length: 891, dtype: object

# %%
df['Las_Name']= df['Name'].str.split(',').str.get(1)

# %%
df[df['Name'].str.contains('john', case= False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8              9         1       3
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 172          173         1       3
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 302          303         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# ...

# %%
a= pd.Timestamp("10-11-2005 9:21 AM")

# %%
import datetime as dt

x= pd.Timestamp(dt.datetime(2023,1,5, 9, 21, 23))

# %%
x.month
# Out:
# 1

# %%
a= pd.DatetimeIndex(['2023/1/1','2023/4/2','2025/4/2'])

# %%
a[0]
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
pd.date_range(start='2023/1/2', end='2023/7/27', freq= '6D')
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-08', '2023-01-14', '2023-01-20',
#                '2023-01-26', '2023-02-01', '2023-02-07', '2023-02-13',
#                '2023-02-19', '2023-02-25', '2023-03-03', '2023-03-09',
#                '2023-03-15', '2023-03-21', '2023-03-27', '2023-04-02',
#                '2023-04-08', '2023-04-14', '2023-04-20', '2023-04-26',
#                '2023-05-02', '2023-05-08', '2023-05-14', '2023-05-20',
#                '2023-05-26', '2023-06-01', '2023-06-07', '2023-06-13',
#                '2023-06-19', '2023-06-25', '2023-07-01', '2023-07-07',
#                '2023-07-13', '2023-07-19', '2023-07-25'],
#               dtype='datetime64[ns]', freq='6D')

# %%
s= pd.Series(['2023/1/1','2023/4/2','2025/4/2'])

# %%
a= pd.to_datetime(s)

# %%
a
# Out:
# 0   2023-01-01
# 1   2023-04-02
# 2   2025-04-02
# dtype: datetime64[ns]

# %%
a.dt.month
# Out:
# 0    1
# 1    4
# 2    4
# dtype: int32
